# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
data=pd.read_csv("https://raw.githubusercontent.com/vkavitha19/MachineLearning/main/datasets/50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['State'] = le.fit_transform(data['State'])
data.head(12)
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70       151377.59        443898.53      0  191792.06
# 2   153441.51       101145.55        407934.54      1  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      1  166187.94
# 5   131876.90        99814.71        362861.36      2  156991.12
# 6   134615.46       147198.87        127716.82      0  156122.51
# 7   130298.13       145530.06        323876.68      1  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88       108679.17        304981.62      0  149759.96
# 10  101913.08       110594.11        229160.95      1  146121.95
# 11  100671.96        91790.61        249744.55      0  144259.40

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
xcopy=x
from sklearn.preprocessing import RobustScaler
sc=RobustScaler()
x=sc.fit_transform(x)
x=pd.DataFrame(x,columns=xcopy.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test)
# Out:
# array([126555.48802381,  85932.31718219,  98752.27196186,  45775.12554664,
#        127534.96072369,  51674.07909748, 108253.39547806, 100825.15032123,
#         97957.41402512, 111692.2637882 , 128075.44221444, 173420.50547382,
#         93785.35427612, 148859.8928341 , 172757.00715764, 155976.21163624,
#         76296.40005435])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, lr.predict(x_test))
# Out:
# 6565.741924586204
